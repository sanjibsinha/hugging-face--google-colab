# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjibsinha/hugging-face--google-colab/blob/main/Sentu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
# !pip install torch

# %%
# !pip install transformers==4.31.0 torch==2.0.1

# %%
from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM

# Load pre-trained tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("gpt2")
model = AutoModelForCausalLM.from_pretrained("gpt2")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
line = "This is the line you want to supply to GPT-2."
input_ids = tokenizer.encode(line, return_tensors="pt")

# %%
# Generate text based on the input line
output = model.generate(input_ids, max_length=50, num_return_sequences=1)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
print(generated_text)
# Out:
# This is the line you want to supply to GPT-2.
#
# The line you want to supply to GPT-2 is the line you want to supply to GPT-2.
#
# The line you want to supply to G

# %%
# !pip install textblob

# %%
from textblob import TextBlob

# %%
line = "I am happy."  # Replace with your sentence
blob = TextBlob(line)

# %%
sentiment = blob.sentiment

# %%
if sentiment.polarity > 0:
    print("Positive sentiment")
elif sentiment.polarity < 0:
    print("Negative sentiment")
else:
    print("Neutral sentiment")
# Out:
# Positive sentiment

# %%
# !pip install flask ipywidgets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.2 MB/s eta 0:00:00
# ...

# %%
from flask import Flask, render_template_string, request
import ipywidgets as widgets
from IPython.display import display, HTML

# %%
app = Flask(__name__)

@app.route("/", methods=["GET", "POST"])
def index():
    if request.method == "POST":
        user_input = request.form["user_input"]
        # Process user input (e.g., sentiment analysis, text generation)
        # ...
        # Here, I'm simply echoing the input back as output
        output = user_input
        return render_template_string(
            """
            <html>
              <body>
                <h1>Simple Web Interface</h1>
                <form method="POST">
                  <input type="text" name="user_input" placeholder="Enter text">
                  <input type="submit" value="Submit">
                </form>
                <h2>Output:</h2>
                <p>{{ output }}</p>
              </body>
            </html>
            """,
            output=output,
        )
    else:
        return render_template_string(
            """
            <html>
              <body>
                <h1>Simple Web Interface</h1>
                <form method="POST">
                  <input type="text" name="user_input" placeholder="Enter text">
                  <input type="submit" value="Submit">
                </form>
              </body>
            </html>
            """
        )

# %%
# !ngrok authtoken <2rsKBLskmkvMEA2DeLLHPcUYwKQ_5krwySidSVpTv16Gycqyr>
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `newline'
# /bin/bash: -c: line 1: `ngrok authtoken <2rsKBLskmkvMEA2DeLLHPcUYwKQ_5krwySidSVpTv16Gycqyr>'

# %%
from google.colab import output
output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
# !pip install pyngrok --quiet
from pyngrok import ngrok

# Open a ngrok tunnel to the HTTP server
public_url = ngrok.connect(port='5000', proto='http').public_url
print(f" * Running on {public_url}")
# Start the Flask server in the background
app.run(port='5000', debug=False, use_reloader=False)
# Out:
# ERROR:pyngrok.process.ngrok:t=2025-01-20T03:07:24+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ERROR:pyngrok.process.ngrok:t=2025-01-20T03:07:24+0000 lvl=eror msg="session closing" obj=tunnels.session err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ...
